# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import data

# %%
path = r'C:\Users\Logan\OneDrive\Desktop\Instacart Basket Analysis'
print(path)
# Out:
# C:\Users\Logan\OneDrive\Desktop\Instacart Basket Analysis

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', '4.7_ords_prods_merge_new variables'))
ords_prods_merge
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %% [markdown]
# # 03. Create subset of dataset 'df'

# %%
# Create subset
# Check the shape of new dataframe for validation
df = ords_prods_merge[:1000000]
df.shape
# Out:
# (1000000, 18)

# %%
# double-check column names
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# # 04. groupby()

# %%
# return average number of orders by department_id
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# perform multiple aggregations ['mean', 'min', 'max']
df.groupby('department_id').agg({'order_number' : ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
# loyalty flag
df['max_order'] = df.groupby('user_id')['order_number'].transform(np.max)
# Out:
# C:\Users\Logan\AppData\Local\Temp\ipykernel_88868\472002073.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_order'] = df.groupby('user_id')['order_number'].transform(np.max)

# %%
df.tail()
# Out:
#         order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 999995   2836489   164627            14                  0                 15
# 999996   1843600   164632             5                  1                 19
# 999997    733106   164632             9                  2                 22
# 999998   1650124   164632            17                  6                 17
# 999999   3378258   164632            22                  6                 10
#
#         days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 999995                     6.0       30489                  2          0
# 999996                     9.0       30489                  2          0
# 999997                    10.0       30489                  3          1
# 999998                    13.0       30489                  1          1
# 999999                    15.0       30489                  3          1
#
# ...

# %%
# Deriving columns with loc()
df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'loyal customer'
df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10) , 'loyalty_flag'] = 'regular customer'
df.loc[df['max_order'] <=10, 'loyalty_flag'] = 'new customer'
# Out:
# C:\Users\Logan\AppData\Local\Temp\ipykernel_88868\1842926685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'loyal customer'

# %%
# check frequency
df['loyalty_flag'].value_counts(dropna = False)
# Out:
# regular customer    463844
# loyal customer      335086
# new customer        201070
# Name: loyalty_flag, dtype: int64

# %%
df[['user_id', 'loyalty_flag', 'max_order']].tail(60)
# Out:
#         user_id      loyalty_flag  max_order
# 999940   164396  regular customer         21
# 999941   164396  regular customer         21
# 999942   164396  regular customer         21
# 999943   164396  regular customer         21
# 999944   164396  regular customer         21
# 999945   164396  regular customer         21
# 999946   164396  regular customer         21
# 999947   164396  regular customer         21
# 999948   164396  regular customer         21
# 999949   164396  regular customer         21
# 999950   164396  regular customer         21
# 999951   164396  regular customer         21
# 999952   164396  regular customer         21
# 999953   164396  regular customer         21
# 999954   164396  regular customer         21
# 999955   164396  regular customer         21
# 999956   164396  regular customer         21
# 999957   164396  regular customer         21
# 999958   164396  regular customer         21
# 999959   164406      new customer          7
# ...

# %% [markdown]
# # 05. Apply groupby(), function, and create new column with instacart data

# %%
# split the data into groups based on user_id
# apply the transform() on order_number to generate max orders by user
# create a new column, max_order to place results

ords_prods_merge['max_order'] = ords_prods_merge.groupby('user_id')['order_number'].transform(np.max)

# %%
ords_prods_merge[['order_id', 'user_id', 'order_number', 'max_order']].head(10)
# Out:
#    order_id  user_id  order_number  max_order
# 0   2539329        1             1         10
# 1   2398795        1             2         10
# 2    473747        1             3         10
# 3   2254736        1             4         10
# 4    431534        1             5         10
# 5   3367565        1             6         10
# 6    550135        1             7         10
# 7   3108588        1             8         10
# 8   2295261        1             9         10
# 9   2550362        1            10         10

# %%
# Create a flag that assigns a "loyalty" label to a user ID based on its corresponding max order value
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

ords_prods_merge.loc[ords_prods_merge['max_order'] <=10, 'loyalty_flag'] = 'New customer'

# %%
# display more rows
pd.set_option('display.max_rows', 100)

# %%
# QA check loyalty flag
ords_prods_merge[['max_order', 'loyalty_flag']].head(100)
# Out:
#     max_order      loyalty_flag
# 0          10      New customer
# 1          10      New customer
# 2          10      New customer
# 3          10      New customer
# 4          10      New customer
# 5          10      New customer
# 6          10      New customer
# 7          10      New customer
# 8          10      New customer
# 9          10      New customer
# 10         22  Regular customer
# 11         22  Regular customer
# 12         22  Regular customer
# 13         22  Regular customer
# 14         22  Regular customer
# 15          9      New customer
# 16          9      New customer
# 17          9      New customer
# 18         33  Regular customer
# 19         20  Regular customer
# 20         20  Regular customer
# 21         11  Regular customer
# 22         11  Regular customer
# 23         27  Regular customer
# 24         27  Regular customer
# 25         27  Regular customer
# 26         27  Regular customer
# 27         27  Regular customer
# ...

# %%
# QA check frequency of data
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
print("length", len(ords_prods_merge))
# Out:
# length 32404859

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
# Export ords_prods_merge dataframe with newly derived columns
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', '4.8_ords_prods_merge_grouping data'))
